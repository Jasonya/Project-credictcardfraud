# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
# read the dataset and print out
c_data = pd.read_csv('creditcard.csv')
c_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
# plot out each features distribution
f = c_data.iloc[:, 0:28].columns

plt.figure(figsize=(20,28*4))
gs = gridspec.GridSpec(14, 2)
for i, c in enumerate(c_data[f]):
    ax = plt.subplot(gs[i])
    sns.distplot(c_data[c][c_data.Class == 1], bins=50, color='red')
    sns.distplot(c_data[c][c_data.Class == 0], bins=50, color='green')
    ax.set_xlabel('')
    ax.set_title(f'Historgram of feature: {c}')
plt.show();

# %%
Fraud = c_data[c_data['Class'] == 1] 
Valid = c_data[c_data['Class'] == 0]
fraud_rate = len(Fraud)/len(Valid)*100
print(f'The fraud_rate: {fraud_rate}')
print(f'fraud transactions: {len(Fraud)}')
print(f'Valid transactions: {len(Valid)}')
# Out:
# The fraud_rate: 0.17304750013189596
# fraud transactions: 492
# Valid transactions: 284315

# %%
print('Amount Detials of Fraudulent Transcation')
print(Fraud.Amount.describe())
print('')
print('Amount Detials of Valid Transcation')
print(Valid.Amount.describe())
# Out:
# Amount Detials of Fraudulent Transcation
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
#
# Amount Detials of Valid Transcation
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# correlation matrix
cor = c_data.corr()
fig = fig = plt.figure(figsize=(12,9))
# observe no correlation over
sns.heatmap(cor, vmax=0.8, square=True)
plt.show()

# most of the feature is not posstive relative, but some of them are
# negative relative

# %%
# dividing the X and Y from the dataset
X = c_data.drop(['Class'], axis=1)
Y = c_data['Class']
X = X.values
Y = Y.values
print(X.shape)
print(Y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_Test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
accl, precl, recall, F1l, Matl, tl = [], [], [], [], [], []

# %% [markdown]
# # IsolationForest

# %%
# Isolation Forest Model (normally used in anomaly detection)
import time
from sklearn.ensemble import IsolationForest
st = time.time()
ifc = IsolationForest(max_samples=len(X_train), contamination=fraud_rate, random_state=1)
ifc.fit(X_train)
scores_pred = ifc.decision_function(X_train)
y_pred = ifc.predict(X_test)
et = time.time()
ifc_t = et - st
ifc_t
# Out:
# 32.69257879257202

# %%
# Reshape the prediction values to 0 for valid, 1 for fraud. 
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1
n_errors = (y_pred != Y_Test).sum()
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
#printing the confusion matrix
from sklearn.metrics import confusion_matrix
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_Test, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
#evaluation of the model
#printing every score of the classifier
#scoring in any thing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef
n_outliers = len(Fraud)
print('the Model used is {}'.format('Isolation Forest'))
acc= accuracy_score(Y_Test,y_pred)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_Test,y_pred)
print('The precision is {}'.format(prec))
rec= recall_score(Y_Test,y_pred)
print('The recall is {}'.format(rec))
f1= f1_score(Y_Test,y_pred)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_Test,y_pred)
print('The Matthews correlation coefficient is{}'.format(MCC))
accl.append(acc)
precl.append(prec)
recall.append(rec)
F1l.append(f1)
Matl.append(MCC)
tl.append(ifc_t)
# Out:
# the Model used is Isolation Forest
# The accuracy is 0.8275165900073733
# The precision is 0.009381620094824978
# The recall is 0.9489795918367347
# The F1-Score is 0.0185795624812706
# The Matthews correlation coefficient is0.08485476193952503

# %% [markdown]
# # RandomForest

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
st = time.time()
rfc = RandomForestClassifier()
rfc.fit(X_train, Y_train)
y_pred = rfc.predict(X_test)
et = time.time()
rfc_t = et - st
rfc_t
# Out:
# 231.09855794906616

# %%
n_outliers = len(Fraud)
n_errors = (y_pred != Y_Test).sum()
print('the Model used is {}'.format('Random Forest Classifier'))
print('error prediction {}'.format(n_errors))
acc= accuracy_score(Y_Test,y_pred)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_Test,y_pred)
print('The precision is {}'.format(prec))
rec= recall_score(Y_Test,y_pred)
print('The recall is {}'.format(rec))
f1= f1_score(Y_Test,y_pred)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_Test,y_pred)
print('The Matthews correlation coefficient is{}'.format(MCC))
accl.append(acc)
precl.append(prec)
recall.append(rec)
F1l.append(f1)
Matl.append(MCC)
tl.append(rfc_t)
# Out:
# the Model used is Random Forest Classifier
# error prediction 23
# The accuracy is 0.9995962220427653
# The precision is 0.9746835443037974
# The recall is 0.7857142857142857
# The F1-Score is 0.8700564971751412
# The Matthews correlation coefficient is0.8749276812909632

# %%
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_Test, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier
st = time.time()
train_scores, test_scores, generlization_error = [],[], []
# demo - findout the better structure for MLP
for i in range(100,200):
    mlpc = MLPClassifier(hidden_layer_sizes=(i,))
    mlpc.fit(X_train, Y_train)
    y_pred = mlpc.predict(X_test)
    tr_score = mlpc.score(X_train, Y_train)
    te_score = mlpc.score(X_test, Y_Test)
    train_scores.append(tr_score)
    test_scores.append(te_score)
    generlization_error.append(tr_score-te_score)

# %%
# plot the figure to see the structure change impact
ne = [i for i in range(100,200)]
plt.subplots(figsize=(15,5))
plt.subplots_adjust(wspace=0.4)
plt.subplot(131)
plt.plot(ne, train_scores)
plt.title('Training Score: More complex is better')
plt.xlabel('Model Complexity')
plt.ylabel('Training Score')
plt.subplot(132)
plt.plot(ne, test_scores)
plt.title("Testing Score: There's a sweetspot")
plt.xlabel('Model Complexity')
plt.ylabel('Testing Score')
plt.subplot(133)
plt.plot(ne, np.subtract(train_scores,test_scores))
plt.title("Generalization Error")
plt.xlabel('Model Complexity')
plt.ylabel('(Training Score) - (Testing Score)')
plt.show()

# %%
best = generlization_error.index(max(generlization_error))
print(f'The best structure: {best}')
# Out:
# The best structure: 34

# %%
st = time.time()
mlpc = MLPClassifier(hidden_layer_sizes=(134,))
mlpc.fit(X_train, Y_train)
y_pred = mlpc.predict(X_test)
et = time.time()
mlpc_t = et - st
mlpc_t

# %%
n_outliers = len(Fraud)
n_errors = (y_pred != Y_Test).sum()
print('the Model used is {}'.format('Muti-Laper Perceptron Classifier'))
print('error prediction {}'.format(n_errors))
acc= accuracy_score(Y_Test,y_pred)
print('The accuracy is {}'.format(acc))
prec= precision_score(Y_Test,y_pred)
print('The precision is {}'.format(prec))
rec= recall_score(Y_Test,y_pred)
print('The recall is {}'.format(rec))
f1= f1_score(Y_Test,y_pred)
print('The F1-Score is {}'.format(f1))
MCC=matthews_corrcoef(Y_Test,y_pred)
print('The Matthews correlation coefficient is{}'.format(MCC))
accl.append(acc)
precl.append(prec)
recall.append(rec)
F1l.append(f1)
Matl.append(MCC)
tl.append(svm_t)
# Out:
# the Model used is Muti-Laper Perceptron Classifier
# error prediction 189
# The accuracy is 0.9966819985253327
# The precision is 0.3172690763052209
# The recall is 0.8061224489795918
# The F1-Score is 0.45533141210374634
# The Matthews correlation coefficient is0.5045197269199327

# %%
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(Y_Test, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS,
 yticklabels=LABELS, annot=True, fmt='d');
plt.title('Confusion matrix')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
